# %% [markdown]
# # 0. Pre-Experiment Setup

# %%
import os

# %%
curr_dir = os.getcwd()
print(curr_dir)
# Out:
# /home/ec2-user/SageMaker/cp-aug-traffic-sign/notebooks

# %%
root_dir = "/home/ec2-user/SageMaker/"

# %%
data_dir = os.path.join("/home/ec2-user/SageMaker/cp-aug-traffic-sign/", "data/")
os.mkdir(data_dir)
data_dir
# Out:
# '/home/ec2-user/SageMaker/cp-aug-traffic-sign/data/'

# %%
# !cd "/home/ec2-user/SageMaker/cp-aug-traffic-sign/" && mkdir TT100K && cd TT100K \
&& wget http://cg.cs.tsinghua.edu.cn/traffic-sign/data_model_code/data.zip \
&& wget http://cg.cs.tsinghua.edu.cn/traffic-sign/data_model_code/code.zip \
&& unzip data.zip \
&& unzip code.zip
# Out:
# --2021-11-22 16:50:25--  http://cg.cs.tsinghua.edu.cn/traffic-sign/data_model_code/data.zip
# Resolving cg.cs.tsinghua.edu.cn (cg.cs.tsinghua.edu.cn)... 101.6.6.219
# Connecting to cg.cs.tsinghua.edu.cn (cg.cs.tsinghua.edu.cn)|101.6.6.219|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19152969603 (18G) [application/zip]
# Saving to: ‘data.zip’
#
# data.zip            100%[===================>]  17.84G  7.96MB/s    in 47m 20s
#
# 2021-11-22 17:37:46 (6.43 MB/s) - ‘data.zip’ saved [19152969603/19152969603]
#
# --2021-11-22 17:37:46--  http://cg.cs.tsinghua.edu.cn/traffic-sign/data_model_code/code.zip
# Resolving cg.cs.tsinghua.edu.cn (cg.cs.tsinghua.edu.cn)... 101.6.6.219
# Connecting to cg.cs.tsinghua.edu.cn (cg.cs.tsinghua.edu.cn)|101.6.6.219|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 801430483 (764M) [application/zip]
# Saving to: ‘code.zip’
#
# ...
